# %% [markdown]
# ## **OOPS Basic Questions**

# %% [markdown]
# **1.** Object-Oriented Programming (OOP)
# A programming paradigm that organizes code using objects and classes to model real-world entities.
#
# **2.** Class in OOP
# A blueprint/template used to create objects.
#
# **3**. Object in OOP
# An instance of a class containing data (attributes) and behavior (methods).
#
# **4.** Abstraction vs Encapsulation
#
# Abstraction: Hiding implementation details and showing only functionality.
#
# Encapsulation: Restricting direct access to data and wrapping data with methods.
#
# **5.** Dunder Methods in Python
# Special methods with double underscores (e.g., __init__, __str__) that define object behavior.
#
# **6.** Inheritance in OOP
# A mechanism where a child class inherits attributes and methods from a parent class.
#
# **7. **Polymorphism in OOP
# Ability of different objects to respond to the same method name differently.
#
# **8.** Encapsulation in Python
# Achieved using private/protected variables (_var, __var) and getter/setter methods.
#
# **9.** Constructor in Python
# The __init__() method that initializes object attributes when an object is created.
#
# **10**. Class and Static Methods
#
# Class method: Uses @classmethod, works with the class (cls).
#
# Static method: Uses @staticmethod, independent of class or instance.
#
# **11.** Method Overloading in Python
# Defining methods with the same name but different parameters (handled using default arguments or *args).
#
# **12.** Method Overriding in OOP
# A child class redefines a method from the parent class.
#
# **13. **Property Decorator in Python
# @property allows a method to be accessed like an attribute.
#
# **14.** Importance of Polymorphism
# Improves code flexibility, reuse, and maintainability.
#
# **15.** Abstract Class in Python
# A class that cannot be instantiated and may contain abstract methods, created using ABC module.
#
# **16.** Advantages of OOP
#
# Code reusability
#
# Modularity
#
# Maintainability
#
# Security through encapsulation
#
# **17.** Multiple Inheritance in Python
# A class inherits from more than one parent class.
#
# **18.** Class Variable vs Instance Variable
#
# Class variable: Shared by all objects.
#
# Instance variable: Unique to each object.
#
# **19.** __str__ vs __repr__
#
# __str__: User-friendly string representation.
#
# __repr__: Developer/debug representation.
#
# **20.** Purpose of super()
# Used to call methods from the parent class.
#
# **21.** Significance of __del__
# Destructor method called when an object is deleted or destroyed.
#
# **22.** @staticmethod vs @classmethod
#
# @staticmethod: No access to class or instance.
#
# @classmethod: Access to class via cls.
#
# **23.** Polymorphism with Inheritance
# Child classes implement the same method differently from the parent class.
#
# **24**. Method Chaining
# Calling multiple methods in a single statement by returning self.
#
# **25.** __call__ Method
# Allows an object to be called like a function.

# %% [markdown]
# # **OOPS Practical Questions**

# %% [markdown]
# All Answers are in order professor

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()
# Out:
# Bark!

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, r):
        self.r = r
    def area(self):
        return math.pi * self.r ** 2

class Rectangle(Shape):
    def __init__(self, l, w):
        self.l = l
        self.w = w
    def area(self):
        return self.l * self.w

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

# %%
class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        self.__balance -= amount

    def check_balance(self):
        return self.__balance

# %%
class Instrument:
    def play(self):
        print("Playing instrument")

class Guitar(Instrument):
    def play(self):
        print("Playing guitar")

class Piano(Instrument):
    def play(self):
        print("Playing piano")

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# %%
class Fraction:
    def __init__(self, n, d):
        self.numerator = n
        self.denominator = d

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# %%
class Rectangle:
    def set_dimensions(self, l, w):
        self.l = l
        self.w = w

    def area(self):
        return self.l * self.w

# %%
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year_published = year

    def get_book_info(self):
        return f"{self.title} by {self.author}, {self.year_published}"

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
